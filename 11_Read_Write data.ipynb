# %% [markdown]
# ### Read / Write data from Excel , Csv , Jason files

# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv',index_col='Respondent')
schema_df= pd.read_csv('data/survey_results_schema.csv',index_col='Column')

# %%
pd.set_option('display.max_columns', 85)  # to get all columns of file in output instead of ...
pd.set_option('display.max_rows', 85)     # to get all rows of file in output instead of ...

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
filt=(df['Country']=='India')
india_df=df.loc[filt]
india_df.head(4)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
#
#                                     Employment Country         Student  \
# Respondent
# ...

# %%
india_df.to_csv('data/modified.csv')     #create new csv file from existing one and save in specific location

# %%
india_df.to_csv('data/modified.tsv' , sep='\t')  #create new tsv file from existing one and save in specific location along with using separators

# %% [markdown]
# ### Excel file ------------- pip install xlwt openpyxl xlrd

# %%
india_df.to_excel('data/modified.xlsx')      #create a new excel file

# %%
test=pd.read_excel('data/modified.xlsx', index_col='OrgSize')     #change index value for excel file.

# %%
test
# Out:
#                           Respondent                              MainBranch  \
# OrgSize
# NaN                                8             I code primarily as a hobby
# 10,000 or more employees          10          I am a developer by profession
# NaN                               15  I am a student who is learning to code
# 10,000 or more employees          50          I am a developer by profession
# 20 to 99 employees                65          I am a developer by profession
# ...                              ...                                     ...
# 1,000 to 4,999 employees       77339                                     NaN
# 500 to 999 employees           79795                                     NaN
# NaN                            83862                                     NaN
# 100 to 499 employees           84299                                     NaN
# 100 to 499 employees           86012                                     NaN
#
# ...

# %% [markdown]
# ### json file

# %%
india_df.to_json('data/modified.json')       #creates a dictionary like file.

# %%
india_df.to_json('data/modified.json',orient='records' , lines=True)    #convert json file to list like file.

# %%
test=pd.read_json('data/modified.json',orient='records' , lines=True) 
test.head()
# Out:
#                                MainBranch Hobbyist  \
# 0             I code primarily as a hobby      Yes
# 1          I am a developer by profession      Yes
# 2  I am a student who is learning to code      Yes
# 3          I am a developer by profession      Yes
# 4          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                               None
#
#                            Employment Country         Student  \
# 0  Not employed, but looking for work   India            None
# ...

# %% [markdown]
# ### sql file ------------- pip install SQLAlchemy--------pip install psycopg2-binary

# %%
from sqlalchemy import create_engine
import psycopg2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-21530d404eb7> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 import psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'
